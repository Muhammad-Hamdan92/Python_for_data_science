# %% [markdown]
# # Data visualization by Matplotlib

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure() 
plt.show()            # an empty figure with no Axes

# %%
fig, ax = plt.subplots()       # a figure with a single Axes

# %%
# a figure with one Axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])

# %%
import seaborn as sns
iris = pd.read_csv(r"C:\Users\mhusm\Documents\Python_for_data_science\00_datasets\0.1_pandas_practice_datasets\iris.csv")
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data=iris, hue="variety")

# %%
sns.jointplot(data=iris, x="sepal.length", y="petal.length", hue="variety")
