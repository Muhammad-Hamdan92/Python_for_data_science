# %% [markdown]
# # Mutable by idexing

# %%
items = ["pen", "ink", "book", "guide"]
items[3] = "eraser"
print(items)

# %% [markdown]
# ### range

# %%
print(list(range(1, 30 , 3)))
# Out:
# [1, 4, 7, 10, 13, 16, 19, 22, 25, 28]
