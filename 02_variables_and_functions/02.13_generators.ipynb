# %% [markdown]
# # Generators in python

# %%
def my_generators():
    yield "A"
    yield "B"
    yield "C"

gen = my_generators()
print(next(gen))
# Out:
# A

# %%
print(next(gen))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(next(gen))
#
# StopIteration:

# %%
gen_exp = (x**2 for x in range(5))
for val in gen_exp:
    print(val)
# Out:
# 0
# 1
# 4
# 9
# 16
