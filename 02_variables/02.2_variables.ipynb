# %% [markdown]
# # variables

# %%
age = 21.5

# %%
print(age)
# Out:
# 21

# %%
name = "Muhammad Hamdan"

# %%
print("I am", age, "years old")
# Out:
# I am 21 years old

# %%
is_student = True

# %%
print(" Am I a student?", is_student)

# %% [markdown]
# # Variables and types
# # variables
# variables is name or box whic store the content and use for manipulation, In python, retrieve when we want.
#
# 1- String\
# 2- Structure\
# 3- Numeric\
# 4- Tuple\
# 5- Dictionary\
# 6- set\
# 7- Boolean
