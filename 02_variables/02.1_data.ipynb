# %% [markdown]
# # **First Notebook**

# %%
print("Hello, World!")
print("welcome to python programming")
# Out:
# Hello, World!
# welcome to python programming

# %%
print("Hello world")
# Out:
# Hello world
