# %% [markdown]
# # Automate EDA by pygwalker

# %%
#import libraries
import pandas as pd
import numpy as np
import pygwalker as pyg

# %%
#load the dataset
df = pd.read_excel('./Dataframes/titanic_df.xlsx')

#load the dataset
df_micro = pd.read_csv('./Dataframes/microbial.csv')

# %%
walker = pyg.walk(df_micro)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00065645690a88cd8uV5LdqhSN9lc3kg" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00065645690a88cd8uV5LdqhSN9lc3kg") {
#             var iframe = document.getElementById("gwalker-00065645690a88cd8uV5LdqhSN9lc3kg");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
