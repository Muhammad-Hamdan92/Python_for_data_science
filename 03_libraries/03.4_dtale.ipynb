# %% [markdown]
# # Automate EDA with dtale

# %%
# import libraries
import pandas as pd
import numpy as np
import dtale

# %%
df = pd.read_excel('./Dataframes/titanic_df.xlsx')

# %%
# Assigning a reference to a running D-Tale process
d = dtale.show(df)

# %%
# using Python's `webbrowser` package it will try and open your server's default browser to this process
d.open_browser()

# %%
# Shutting down D-Tale process
d.kill()
# Out:
# 2026-07-10 22:18:23,216 - INFO     - Executing shutdown...
# 2026-07-10 22:18:23,221 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
