# %% [markdown]
# # Automated EDA by using fg-data-profiling

# %%
# import the library
import pandas as pd
import numpy as np
import ydata_profiling
# import the library
import pandas as pd
import numpy as np
import ydata_profiling
import tqdm as notebook_tqdm
from ydata_profiling import ProfileReport

# %%
# load the data
df = pd.read_excel("./Dataframes/titanic_df.xlsx")

# %%
# make profile of data
profile = ProfileReport(df, title="titanic Profiling Report")

# %%
profile.to_file("./ydataprofile_report/titanic_profile_report.html")
# Out:
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 71.60it/s]

# %% [markdown]
# # EDA of microbial dataset

# %%
df_micro = pd.read_csv('./Dataframes/microbial.csv')

# %%
micro_profile = ProfileReport(df_micro, title="Microbial profiling repoet")

# %%
micro_profile.to_file('./ydataprofile_report/micro_profile_report.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 47.69it/s]
