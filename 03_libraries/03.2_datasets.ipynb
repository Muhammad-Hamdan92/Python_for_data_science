# %% [markdown]
# # Build in datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# save to excel 
df.to_excel('./Dataframes/titanic.xlsx', index = False)

# %%
# excel to python
df_titanic = pd.read_excel('./Dataframes/titanic_df.xlsx')

# %%
# read the csv file of microbial dataset
df_micro = pd.read_csv("C:/Users/BEST LAPTOP/Desktop/microbial.csv")

# %%
df_micro.head()
# Out:
#         bacteria   antibiotic  resistance         region  year  age gender  \
# 0  P. aeruginosa   Vancomycin   83.740294         Africa  2018   52      F
# 1   A. baumannii  Methicillin   54.298686  North America  2019   93      F
# 2  K. pneumoniae  Methicillin  100.000000         Europe  2022   15      F
# 3   A. baumannii  Amoxicillin   45.493537           Asia  2018   72      M
# 4   A. baumannii  Amoxicillin   63.460719           Asia  2018   61      M
#
#   prior_infection_site  intensive_care_metrics  cumulative_days_on_antibiotic  \
# 0              Urinary                       9                              5
# 1              Urinary                       9                              0
# 2          Respiratory                      14                              0
# 3                  NaN                      14                             10
# 4                  NaN                      35                              6
#
#    days_since_last_hospital_stay
# ...

# %%
#after moving the file from dekstop to project folder, move to dataframes folder
df_micro.to_csv('./Dataframes/microbial.csv')
