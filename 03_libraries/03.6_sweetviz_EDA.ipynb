# %% [markdown]
# # Automated EDA by sweetviz

# %%
import pandas as pd
import sweetviz as sv

df_micro = pd.read_csv('./Dataframes/microbial.csv')

my_report = sv.analyze(df_micro)
my_report.show_html('./sweetviz_report/microbial.html') # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
# Feature: Unnamed: 0                          |▊         | [  8%]   00:00 -> (00:00 left)
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)
# Report ./sweetviz_report/microbial.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
