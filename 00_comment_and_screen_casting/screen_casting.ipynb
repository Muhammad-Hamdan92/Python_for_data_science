# %% [markdown]
# # Screen casting
# This will show the keyboard key on the screen to student or learning person. It can help them for better under standing and will know what key we press.
# # crtl+shift+p is the short key

# %% [markdown]
# # Further setting
# You can also go on seetting option in bottom left corner, type the screen casting on search bar and you will see the option, you acn change it as you wish.
