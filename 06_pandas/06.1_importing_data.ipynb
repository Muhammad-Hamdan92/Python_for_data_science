# %% [markdown]
# # Pandas library

# %%
import pandas as pd  # first step

# %%
# import dataset by clipboarding
df = pd.read_clipboard()
df           # only used fro quick analysis
# Out:
#          contig   student      cov     len      gc
# 0    student0_1  student0  29.0114  255873  0.4995
# 1    student0_2  student0  31.5053  190425  0.5151
# 2    student0_3  student0  39.5121  149891  0.5077
# 3    student0_4  student0  37.9206  135958  0.5212
# 4    student0_5  student0  34.0143  121845  0.5204
# 5    student0_6  student0  30.4397  117759  0.5067
# 6    student0_7  student0  33.0765  114165  0.5210
# 7    student0_8  student0  40.6539  112487  0.5224
# 8    student0_9  student0  34.6739   97943  0.5203
# 9   student0_10  student0  34.1807   96681  0.5237
# 10  student0_11  student0  30.8479   93818  0.5095
# 11  student0_12  student0  34.0987   92190  0.5030
# 12  student0_13  student0  43.4598   88743  0.5262
# 13  student0_14  student0  36.3573   85173  0.5128
# 14  student0_15  student0  40.7952   83655  0.5075

# %% [markdown]
# ### Importing datasets from excel

# %%
df_excel = pd.read_excel("../00_datasets/titanic_df.xlsx")
df_excel
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## import csv files

# %%
df_csv = pd.read_csv("../00_datasets/microbial.csv")
df_csv
# Out:
#       Unnamed: 0       bacteria     antibiotic  resistance         region  \
# 0              0  P. aeruginosa     Vancomycin   83.740294         Africa
# 1              1   A. baumannii    Methicillin   54.298686  North America
# 2              2  K. pneumoniae    Methicillin  100.000000         Europe
# 3              3   A. baumannii    Amoxicillin   45.493537           Asia
# 4              4   A. baumannii    Amoxicillin   63.460719           Asia
# ...          ...            ...            ...         ...            ...
# 3495        3495        E. coli  Ciprofloxacin   44.199565           Asia
# 3496        3496   A. baumannii  Ciprofloxacin   50.912172         Africa
# 3497        3497        E. coli     Vancomycin   90.270913           Asia
# 3498        3498        E. coli    Amoxicillin   47.194067  North America
# 3499        3499        E. coli    Amoxicillin   59.293169         Africa
#
#       year  age gender prior_infection_site  intensive_care_metrics  \
# ...
