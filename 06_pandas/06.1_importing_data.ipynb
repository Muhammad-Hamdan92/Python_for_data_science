# %% [markdown]
# # Pandas library

# %%
import pandas as pd  # first step

# %%
# import dataset by clipboarding
df = pd.read_clipboard()
df           # only used fro quick analysis
# Out:
#    Name,Age,Heigth
# 0  Muhammad,12,6.0
# 1       Ali,30,5.5
# 2     Soban,26,6.0
# 3    Hamdan,46,7.0
# 4    Nibras,23,5.4

# %% [markdown]
# ### Importing datasets from excel

# %%
df_excel = pd.read_excel("../00_datasets/titanic_df.xlsx")
df_excel
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## import csv files

# %%
df_csv = pd.read_csv("../00_datasets/microbial.csv")
df_csv
# Out:
#       Unnamed: 0       bacteria     antibiotic  resistance         region  \
# 0              0  P. aeruginosa     Vancomycin   83.740294         Africa
# 1              1   A. baumannii    Methicillin   54.298686  North America
# 2              2  K. pneumoniae    Methicillin  100.000000         Europe
# 3              3   A. baumannii    Amoxicillin   45.493537           Asia
# 4              4   A. baumannii    Amoxicillin   63.460719           Asia
# ...          ...            ...            ...         ...            ...
# 3495        3495        E. coli  Ciprofloxacin   44.199565           Asia
# 3496        3496   A. baumannii  Ciprofloxacin   50.912172         Africa
# 3497        3497        E. coli     Vancomycin   90.270913           Asia
# 3498        3498        E. coli    Amoxicillin   47.194067  North America
# 3499        3499        E. coli    Amoxicillin   59.293169         Africa
#
#       year  age gender prior_infection_site  intensive_care_metrics  \
# ...

# %% [markdown]
# ## import tsv data

# %%
df_txt = pd.read_csv('../00_datasets/microbial.tsv', sep='\t')
df_txt
# Out:
#       Unnamed: 0       bacteria     antibiotic  resistance         region  \
# 0              0  P. aeruginosa     Vancomycin   83.740294         Africa
# 1              1   A. baumannii    Methicillin   54.298686  North America
# 2              2  K. pneumoniae    Methicillin  100.000000         Europe
# 3              3   A. baumannii    Amoxicillin   45.493537           Asia
# 4              4   A. baumannii    Amoxicillin   63.460719           Asia
# ...          ...            ...            ...         ...            ...
# 3495        3495        E. coli  Ciprofloxacin   44.199565           Asia
# 3496        3496   A. baumannii  Ciprofloxacin   50.912172         Africa
# 3497        3497        E. coli     Vancomycin   90.270913           Asia
# 3498        3498        E. coli    Amoxicillin   47.194067  North America
# 3499        3499        E. coli    Amoxicillin   59.293169         Africa
#
#       year  age gender prior_infection_site  intensive_care_metrics  \
# ...

# %% [markdown]
# # Dummy Dataset

# %%
# create dataframe from dictionary 
df = {'Name':['Muhammad', 'Ali', 'Soban', 'Hamdan', 'Nibras'],
      'Age':[12,30,26,46,23],
      'Heigth':[6,5.5,6,7,5.4]}  #heigth is in inches
df
df_2= pd.DataFrame(df)
df_2
# Out:
#        Name  Age  Heigth
# 0  Muhammad   12     6.0
# 1       Ali   30     5.5
# 2     Soban   26     6.0
# 3    Hamdan   46     7.0
# 4    Nibras   23     5.4

# %% [markdown]
# ## making json datasets

# %%
df_json = {
  "company": "Nexus Media Group",
  "metadata": {
    "version": "2.4.1",
    "generatedAt": "2026-07-17T18:22:00Z",
    "totalRecords": 3
  },
  "employees": [
    {
      "id": "EMP-0091",
      "personal": {
        "firstName": "Sarah",
        "lastName": "Chen",
        "age": 34,
        "contact": {
          "email": "s.chen@nexusmedia.com",
          "phone": "+1-555-019-2834",
          "address": {
            "street": "742 Evergreen Terrace",
            "city": "Springfield",
            "state": "IL",
            "zipCode": "62704"
          }
        }
      },
      "employment": {
        "role": "Lead Data Scientist",
        "department": "Analytics",
        "salary": 135000,
        "isRemote": True,
        "startDate": "2021-04-12",
        "skills": ["Python", "SQL", "Machine Learning", "PyTorch", "Tableau"]
      },
      "projects": [
        {
          "projectId": "PRJ-901",
          "name": "Predictive Churn Model",
          "status": "Completed",
          "budget": 45000.00
        },
        {
          "projectId": "PRJ-905",
          "name": "Automated Content Tagging",
          "status": "In Progress",
          "budget": 120000.50
        }
      ]
    },
    {
      "id": "EMP-0092",
      "personal": {
        "firstName": "Marcus",
        "lastName": "Rodriguez",
        "age": 29,
        "contact": {
          "email": "m.rodriguez@nexusmedia.com",
          "phone": "+1-555-014-7721",
          "address": {
            "street": "112 Ocean Drive",
            "city": "Miami",
            "state": "FL",
            "zipCode": "33139"
          }
        }
      },
      "employment": {
        "role": "Senior DevOps Engineer",
        "department": "Infrastructure",
        "salary": 142000,
        "isRemote": False,
        "startDate": "2023-09-01",
        "skills": ["AWS", "Docker", "Kubernetes", "Terraform", "CI/CD"]
      },
      "projects": [
        {
          "projectId": "PRJ-702",
          "name": "Cloud Migration Phase 2",
          "status": "In Progress",
          "budget": 350000.00
        }
      ]
    },
    {
      "id": "EMP-0093",
      "personal": {
        "firstName": "Elena",
        "lastName": "Rostova",
        "age": 41,
        "contact": {
          "email": "e.rostova@nexusmedia.com",
          "phone": "+1-555-016-9988",
          "address": {
            "street": "456 Maple Avenue",
            "city": "Boston",
            "state": "MA",
            "zipCode": "02115"
          }
        }
      },
      "employment": {
        "role": "Product Director",
        "department": "Product Management",
        "salary": 165000,
        "isRemote": True,
        "startDate": "2018-11-15",
        "skills": ["Agile", "Scrum", "Roadmapping", "UI/UX Strategy"]
      },
      "projects": [
        {
          "projectId": "PRJ-501",
          "name": "Mobile App Redesign",
          "status": "Planning",
          "budget": 85000.00
        }
      ]
    }
  ],
  "systemSettings": {
    "allowedRoles": ["Admin", "Manager", "Employee", "Guest"],
    "security": {
      "twoFactorAuth": True,
      "sessionTimeoutMinutes": 30,
      "ipWhitelist": ["192.168.1.1", "10.0.0.1"]
    }
  }
}

df_json
# Out:
# {'company': 'Nexus Media Group',
#  'metadata': {'version': '2.4.1',
#   'generatedAt': '2026-07-17T18:22:00Z',
#   'totalRecords': 3},
#  'employees': [{'id': 'EMP-0091',
#    'personal': {'firstName': 'Sarah',
#     'lastName': 'Chen',
#     'age': 34,
#     'contact': {'email': 's.chen@nexusmedia.com',
#      'phone': '+1-555-019-2834',
#      'address': {'street': '742 Evergreen Terrace',
#       'city': 'Springfield',
#       'state': 'IL',
#       'zipCode': '62704'}}},
#    'employment': {'role': 'Lead Data Scientist',
#     'department': 'Analytics',
#     'salary': 135000,
#     'isRemote': True,
#     'startDate': '2021-04-12',
#     'skills': ['Python', 'SQL', 'Machine Learning', 'PyTorch', 'Tableau']},
#    'projects': [{'projectId': 'PRJ-901',
#      'name': 'Predictive Churn Model',
#      'status': 'Completed',
#      'budget': 45000.0},
#     {'projectId': 'PRJ-905',
#      'name': 'Automated Content Tagging',
#      'status': 'In Progress',
# ...

# %%
df_json
##save the datasets
import json #this build in library

with open('../00_datasets/0.1_pandas_practice_datasets/employee.json', 'w') as f:
	json.dump(df_json, f, indent=2)

import pandas as pd

## view pandas the cleanest way to save the json file	
df_employees = pd.json_normalize(df_json['employees']) # convert the employees list into a DataFrame 

df_employees.to_json('../00_datasets/0.1_pandas_practice_datasets/employee_1.json', orient='records') # and save via pandas

# %%
df_2.to_clipboard()

# %% [markdown]
# ##### convert dataframe into file by using pandas command

# %%
df.to_excel('../00_datasets/0.1_pandas_practice_datasets/people.xlsx', index=False)
df.to_csv('../00_datasets/0.1_pandas_practice_datasets/people.csv', index=False)

# %% [markdown]
# ## Reading data from path

# %%
import pandas as pd

# %%
#step 1: Change the '\' into '/' "C:\Users\mhusm\Documents\Python_for_data_science\00_datasets\titanic.xlsx"
df = pd.read_excel("C:/Users/mhusm/Documents/Python_for_data_science/00_datasets/titanic.xlsx")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = pd.read_excel(r"C:\Users\mhusm\Documents\Python_for_data_science\00_datasets\titanic.xlsx", sheet_name=0)
df    ## here r is teh string literal and 'sheet_name' function is used to access the sheet no.'by using name or index
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# **r** in pandas show that the path is raw literal string so python treat it as **literal character** rather than **escape character** because '\' it is used to break the string..... such as if we used '\n' means add in new line or if used '\t' means add space

# %%
# example with \
print("Hello "world" !")  ## here python think that string is end at second " marks
# Out:
#   Cell In[9], line 2
#     print("Hello "world" !")  ## here python think that string is end at second " marks
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# with \
print("Hello \"world\" !")
# Out:
# Hello "world" !

# %% [markdown]
# \n = Starts a new line.\
# \t = Inserts a tab space\

# %% [markdown]
# you can also read file, having space between name of file e.g "world population", but best practice is that used '_' between name such as "world_population"

# %%
df = pd.read_csv(r"C:\Users\mhusm\Documents\Python_for_data_science\00_datasets\micro bial.csv")
df
# Out:
#       Unnamed: 0       bacteria     antibiotic  resistance         region  \
# 0              0  P. aeruginosa     Vancomycin   83.740294         Africa
# 1              1   A. baumannii    Methicillin   54.298686  North America
# 2              2  K. pneumoniae    Methicillin  100.000000         Europe
# 3              3   A. baumannii    Amoxicillin   45.493537           Asia
# 4              4   A. baumannii    Amoxicillin   63.460719           Asia
# ...          ...            ...            ...         ...            ...
# 3495        3495        E. coli  Ciprofloxacin   44.199565           Asia
# 3496        3496   A. baumannii  Ciprofloxacin   50.912172         Africa
# 3497        3497        E. coli     Vancomycin   90.270913           Asia
# 3498        3498        E. coli    Amoxicillin   47.194067  North America
# 3499        3499        E. coli    Amoxicillin   59.293169         Africa
#
#       year  age gender prior_infection_site  intensive_care_metrics  \
# ...

# %% [markdown]
# ### Reading tabular dataset

# %%
import pandas as pd

df_tabuler = pd.read_table('../00_datasets/microbial.tsv', sep = '\t', header=0)

df_tabuler
# Out:
#       Unnamed: 0       bacteria     antibiotic  resistance         region  \
# 0              0  P. aeruginosa     Vancomycin   83.740294         Africa
# 1              1   A. baumannii    Methicillin   54.298686  North America
# 2              2  K. pneumoniae    Methicillin  100.000000         Europe
# 3              3   A. baumannii    Amoxicillin   45.493537           Asia
# 4              4   A. baumannii    Amoxicillin   63.460719           Asia
# ...          ...            ...            ...         ...            ...
# 3495        3495        E. coli  Ciprofloxacin   44.199565           Asia
# 3496        3496   A. baumannii  Ciprofloxacin   50.912172         Africa
# 3497        3497        E. coli     Vancomycin   90.270913           Asia
# 3498        3498        E. coli    Amoxicillin   47.194067  North America
# 3499        3499        E. coli    Amoxicillin   59.293169         Africa
#
#       year  age gender prior_infection_site  intensive_care_metrics  \
# ...

# %%
## reading csv via table function
import pandas as pd

df_csv = pd.read_table('../00_datasets/microbial.csv', sep = ',', header=0)

df_csv
# Out:
#       Unnamed: 0       bacteria     antibiotic  resistance         region  \
# 0              0  P. aeruginosa     Vancomycin   83.740294         Africa
# 1              1   A. baumannii    Methicillin   54.298686  North America
# 2              2  K. pneumoniae    Methicillin  100.000000         Europe
# 3              3   A. baumannii    Amoxicillin   45.493537           Asia
# 4              4   A. baumannii    Amoxicillin   63.460719           Asia
# ...          ...            ...            ...         ...            ...
# 3495        3495        E. coli  Ciprofloxacin   44.199565           Asia
# 3496        3496   A. baumannii  Ciprofloxacin   50.912172         Africa
# 3497        3497        E. coli     Vancomycin   90.270913           Asia
# 3498        3498        E. coli    Amoxicillin   47.194067  North America
# 3499        3499        E. coli    Amoxicillin   59.293169         Africa
#
#       year  age gender prior_infection_site  intensive_care_metrics  \
# ...

# %% [markdown]
# ### Reading json file

# %%
import pandas as pd 

df_json = pd.read_json('../00_datasets/0.1_pandas_practice_datasets/employee_1.json')

df_json
# Out:
#          id                                           projects  \
# 0  EMP-0091  [{'projectId': 'PRJ-901', 'name': 'Predictive ...
# 1  EMP-0092  [{'projectId': 'PRJ-702', 'name': 'Cloud Migra...
# 2  EMP-0093  [{'projectId': 'PRJ-501', 'name': 'Mobile App ...
#
#   personal.firstName personal.lastName  personal.age  \
# 0              Sarah              Chen            34
# 1             Marcus         Rodriguez            29
# 2              Elena           Rostova            41
#
#        personal.contact.email personal.contact.phone  \
# 0       s.chen@nexusmedia.com        +1-555-019-2834
# 1  m.rodriguez@nexusmedia.com        +1-555-014-7721
# 2    e.rostova@nexusmedia.com        +1-555-016-9988
#
#   personal.contact.address.street personal.contact.address.city  \
# 0           742 Evergreen Terrace                   Springfield
# 1                 112 Ocean Drive                         Miami
# 2                456 Maple Avenue                        Boston
#
# ...
